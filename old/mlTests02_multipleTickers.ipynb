# %% [markdown]
# ## Run the below import cell first

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import sqlite3
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import KNNImputer

# %% [markdown]
# ## Run the cell below to get the data loaded and mostly ready

# %%
# condensing several of the above cells into this one
# One

conn = sqlite3.connect('stockPrediction.db')

query = "SELECT r.stock_symbol, l.price_datetime, l.open_price, l.high_price, l.low_price, l.close_price, l.volume, l.dividends, l.stock_splits FROM price_history l INNER JOIN stock r ON r.stock_id = l.stock_id;"

symbols = conn.execute('SELECT stock_symbol FROM stock')
symbols = symbols.fetchall()
symbols = [i[0] for i in symbols]
symbols = [i for i in symbols if i not in symbols]

# columns = pd.MultiIndex.from_product([[i for i in symbols], ['open_price', 'high_price', 'low_price', 'close_price']], names=['symbol', 'type'])

df = pd.read_sql(query, conn, index_col=['stock_symbol', 'price_datetime'])

# Two

# remove stocks w/ less than 1000 data points
s = df.groupby(level=0).size()
# s = s.where(s > 1000).dropna()
s = s.where(s > 1550).dropna()  # playing around w/ different values here to get a model that can actually be trained
dfs = s.to_frame()
dfs = dfs.reset_index()
df = df.reset_index()
# dfs

# Three
df = pd.merge(df, dfs, how='inner', left_on='stock_symbol', right_on='stock_symbol', left_index=True)
df = df.drop_duplicates()
# this line below added in on 5/14 22:37:
df = df.drop(columns=[0])

# Four

# df = df.drop_duplicates(subset=['price_datetime'])
df = df.set_index(['price_datetime', 'stock_symbol']).unstack(['stock_symbol'])
df
# Out:
#                     open_price                                          \
# stock_symbol              AACG   AAIC    AAME       AAU    ABEO   ABEV
# price_datetime
# 2021-02-11 09:30:00     6.0200  3.690  5.6100  0.963900  3.4550  2.820
# 2021-02-11 09:45:00     6.2300  3.710  5.4500  0.918901  3.3796  2.855
# 2021-02-11 10:00:00     6.0350  3.740  5.4999  0.936800  3.3070  2.830
# 2021-02-11 10:15:00     5.9700  3.740  5.4100  0.939900  3.2886  2.835
# 2021-02-11 10:30:00     5.9800  3.730  5.4466  0.947001  3.3300  2.830
# ...                        ...    ...     ...       ...     ...    ...
# 2021-05-12 15:15:00     2.7157  3.920  4.0100  0.522700  1.3950  3.235
# 2021-05-12 15:30:00     2.7499  3.900  4.0100  0.515100  1.3950  3.225
# 2021-05-12 15:45:00     2.7400  3.905  4.0200  0.519600  1.4000  3.225
# 2021-05-12 15:59:18        NaN    NaN     NaN       NaN     NaN    NaN
# 2021-05-12 15:59:59        NaN    NaN     NaN       NaN     NaN    NaN
#
#                                                     ... stock_splits       \
# stock_symbol           ABIO   ABML    ABUS    ACER  ...          YPF YTRA
# price_datetime                                      ...
# 2021-02-11 09:30:00  5.2885  3.720  4.4100  4.1500  ...          NaN  NaN
# 2021-02-11 09:45:00  5.4800  3.690  4.4213  4.1356  ...          NaN  NaN
# 2021-02-11 10:00:00  5.4200  3.670  4.5393  4.3001  ...          NaN  NaN
# 2021-02-11 10:15:00  5.3500  3.620  4.5900  4.4000  ...          NaN  NaN
# 2021-02-11 10:30:00  5.3900  3.610  4.5200  4.5300  ...          NaN  NaN
# ...                     ...    ...     ...     ...  ...          ...  ...
# 2021-05-12 15:15:00  3.1900  1.520  2.7000     NaN  ...            0    0
# 2021-05-12 15:30:00  3.1600  1.570  2.6950  2.6100  ...            0    0
# 2021-05-12 15:45:00  3.1800  1.575  2.6991  2.6100  ...            0    0
# 2021-05-12 15:59:18     NaN    NaN     NaN     NaN  ...          NaN  NaN
# 2021-05-12 15:59:59     NaN    NaN     NaN     NaN  ...          NaN  NaN
#
#
# stock_symbol         YVR ZIOP ZKIN ZNOG  ZOM ZSAN  ZVO ZYNE
# price_datetime
# 2021-02-11 09:30:00  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2021-02-11 09:45:00  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2021-02-11 10:00:00  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2021-02-11 10:15:00  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2021-02-11 10:30:00  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                  ...  ...  ...  ...  ...  ...  ...  ...
# 2021-05-12 15:15:00    0    0    0    0    0    0    0    0
# 2021-05-12 15:30:00    0    0    0    0    0    0    0    0
# 2021-05-12 15:45:00    0    0    0    0    0    0    0    0
# 2021-05-12 15:59:18  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2021-05-12 15:59:59  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [1677 rows x 4515 columns]

# %% [markdown]
# *Cell Below removes weird datetime values. Run it.*

# %%
# This cell removes weird datetime values
df = df.reset_index()
df['price_datetime'] = pd.to_datetime(df['price_datetime'])
df = df[(df['price_datetime'].dt.second == 0) & ((df['price_datetime'].dt.minute == 0) | (df['price_datetime'].dt.minute == 15) | (df['price_datetime'].dt.minute == 30) | (df['price_datetime'].dt.minute == 45))]
df = df.set_index('price_datetime')

# %%
# attempting once again to impute
columns = df.close_price.columns
df = df.reset_index()
imputer = KNNImputer(n_neighbors=2, weights='distance')
imputed_data = imputer.fit_transform(df[['close_price']])
clean_data = pd.DataFrame(imputed_data, columns=columns)
# clean_data['price_datetime'] = df['price_datetime']
# df = pd.merge(df, clean_data, on='price_datetime')
clean_data
# Out:
# stock_symbol    AACG    AAIC  AAME       AAU    ABEO    ABEV    ABIO    ABML  \
# 0             6.2300  3.7270  5.40  0.920000  3.3700  2.8600  5.4354  3.6865
# 1             6.1000  3.7400  5.47  0.936200  3.3043  2.8350  5.4300  3.6600
# 2             5.9783  3.7400  5.42  0.932201  3.2800  2.8400  5.3500  3.6100
# 3             5.9971  3.7390  5.45  0.948600  3.3281  2.8311  5.3700  3.6200
# 4             5.9125  3.7250  5.41  0.999800  3.3106  2.8300  5.4111  3.6145
# ...              ...     ...   ...       ...     ...     ...     ...     ...
# 1633          2.7400  3.9500  4.00  0.523200  1.4400  3.2710  3.2100  1.5250
# 1634          2.7100  3.9250  4.00  0.522800  1.3900  3.2350  3.2098  1.5200
# 1635          2.7000  3.9050  4.01  0.520199  1.4000  3.2250  3.1600  1.5700
# 1636          2.7200  3.9099  4.02  0.519500  1.4050  3.2250  3.1650  1.5700
# 1637          2.7400  3.9100  4.19  0.515100  1.4100  3.2200  3.1900  1.5835
#
# stock_symbol    ABUS      ACER  ...       YPF      YTRA    YVR      ZIOP  \
# 0             4.4300  4.160000  ...  4.758828  2.719063  2.230  4.702689
# 1             4.5400  4.360000  ...  4.758858  2.718976  2.230  4.702711
# 2             4.6000  4.400000  ...  4.758850  2.719001  2.230  4.702705
# 3             4.5292  4.525000  ...  4.758861  2.718968  2.230  4.702713
# 4             4.5150  4.458200  ...  4.758872  2.718936  2.230  4.702721
# ...              ...       ...  ...       ...       ...    ...       ...
# 1633          2.7200  2.650000  ...  4.130000  1.828900  1.925  3.120000
# 1634          2.7100  2.638000  ...  4.115000  1.810000  1.930  3.110000
# 1635          2.6900  2.615482  ...  4.130000  1.800000  1.900  3.090000
# 1636          2.6950  2.620000  ...  4.125000  1.793200  1.910  3.085000
# 1637          2.7150  2.610000  ...  4.150000  1.770000  1.900  3.060000
#
# stock_symbol      ZKIN      ZNOG       ZOM      ZSAN       ZVO      ZYNE
# 0             6.326563  0.849411  2.429055  1.669108  6.900830  5.791376
# 1             6.324401  0.849417  2.429166  1.669021  6.900284  5.791554
# 2             6.325023  0.849415  2.429134  1.669046  6.900441  5.791503
# 3             6.324205  0.849417  2.429176  1.669013  6.900234  5.791570
# 4             6.323410  0.849419  2.429217  1.668981  6.900033  5.791636
# ...                ...       ...       ...       ...       ...       ...
# 1633          4.625000  0.600000  0.783400  0.744951  3.470000  4.300000
# 1634          4.590000  0.595050  0.780300  0.746700  3.450000  4.260000
# 1635          4.600000  0.599000  0.775799  0.746300  3.460000  4.260000
# 1636          4.600000  0.610000  0.771300  0.744800  3.430000  4.250000
# 1637          4.620000  0.610000  0.776700  0.741200  3.430000  4.250000
#
# [1638 rows x 645 columns]

# %% [markdown]
# *Cell below is not necessary?*

# %%
# This cell serves as an alternative to the above, avoiding the imputing entirely.
columns = df.close_price.columns
# clean_data = pd.DataFrame(df[['close_price']], columns=columns)
clean_data = df['close_price']
clean_data
# Out:
# stock_symbol           AACG    AAIC  AAME       AAU    ABEO    ABEV    ABIO  \
# price_datetime
# 2021-02-11 09:30:00  6.2300  3.7270  5.40  0.920000  3.3700  2.8600  5.4354
# 2021-02-11 09:45:00  6.1000  3.7400  5.47  0.936200  3.3043  2.8350  5.4300
# 2021-02-11 10:00:00  5.9783  3.7400  5.42  0.932201  3.2800  2.8400  5.3500
# 2021-02-11 10:15:00  5.9971  3.7390  5.45  0.948600  3.3281  2.8311  5.3700
# 2021-02-11 10:30:00  5.9125  3.7250  5.41  0.999800  3.3106  2.8300  5.4111
# ...                     ...     ...   ...       ...     ...     ...     ...
# 2021-05-12 14:45:00  2.7400  3.9500  4.00  0.523200  1.4400  3.2710  3.2100
# 2021-05-12 15:00:00  2.7100  3.9250  4.00  0.522800  1.3900  3.2350  3.2098
# 2021-05-12 15:15:00  2.7000  3.9050  4.01  0.520199  1.4000  3.2250  3.1600
# 2021-05-12 15:30:00  2.7200  3.9099  4.02  0.519500  1.4050  3.2250  3.1650
# 2021-05-12 15:45:00  2.7400  3.9100  4.19  0.515100  1.4100  3.2200  3.1900
#
# stock_symbol           ABML    ABUS    ACER  ...    YPF    YTRA    YVR   ZIOP  \
# price_datetime                               ...
# 2021-02-11 09:30:00  3.6865  4.4300  4.1600  ...    NaN     NaN    NaN    NaN
# 2021-02-11 09:45:00  3.6600  4.5400  4.3600  ...    NaN     NaN    NaN    NaN
# 2021-02-11 10:00:00  3.6100  4.6000  4.4000  ...    NaN     NaN    NaN    NaN
# 2021-02-11 10:15:00  3.6200  4.5292  4.5250  ...    NaN     NaN    NaN    NaN
# 2021-02-11 10:30:00  3.6145  4.5150  4.4582  ...    NaN     NaN    NaN    NaN
# ...                     ...     ...     ...  ...    ...     ...    ...    ...
# 2021-05-12 14:45:00  1.5250  2.7200  2.6500  ...  4.130  1.8289  1.925  3.120
# 2021-05-12 15:00:00  1.5200  2.7100  2.6380  ...  4.115  1.8100  1.930  3.110
# 2021-05-12 15:15:00  1.5700  2.6900     NaN  ...  4.130  1.8000  1.900  3.090
# 2021-05-12 15:30:00  1.5700  2.6950  2.6200  ...  4.125  1.7932  1.910  3.085
# 2021-05-12 15:45:00  1.5835  2.7150  2.6100  ...  4.150  1.7700  1.900  3.060
#
# stock_symbol          ZKIN     ZNOG       ZOM      ZSAN   ZVO  ZYNE
# price_datetime
# 2021-02-11 09:30:00    NaN      NaN       NaN       NaN   NaN   NaN
# 2021-02-11 09:45:00    NaN      NaN       NaN       NaN   NaN   NaN
# 2021-02-11 10:00:00    NaN      NaN       NaN       NaN   NaN   NaN
# 2021-02-11 10:15:00    NaN      NaN       NaN       NaN   NaN   NaN
# 2021-02-11 10:30:00    NaN      NaN       NaN       NaN   NaN   NaN
# ...                    ...      ...       ...       ...   ...   ...
# 2021-05-12 14:45:00  4.625  0.60000  0.783400  0.744951  3.47  4.30
# 2021-05-12 15:00:00  4.590  0.59505  0.780300  0.746700  3.45  4.26
# 2021-05-12 15:15:00  4.600  0.59900  0.775799  0.746300  3.46  4.26
# 2021-05-12 15:30:00  4.600  0.61000  0.771300  0.744800  3.43  4.25
# 2021-05-12 15:45:00  4.620  0.61000  0.776700  0.741200  3.43  4.25
#
# [1638 rows x 645 columns]

# %% [markdown]
# *Ignore the cell below for now*

# %%
# move the dataframes around as necessary and once again set the index to price_datetime
df['close_price'] = clean_data
df = df.set_index('price_datetime')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-8762019ef842> in <module>
#       1 # move the dataframes around as necessary and once again set the index to price_datetime
#       2 df['close_price'] = clean_data
# ----> 3 df = df.set_index('price_datetime')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['price_datetime'] are in the columns"

# %%
df.index
# Out:
# DatetimeIndex(['2021-02-11 09:30:00', '2021-02-11 09:45:00',
#                '2021-02-11 10:00:00', '2021-02-11 10:15:00',
#                '2021-02-11 10:30:00', '2021-02-11 10:45:00',
#                '2021-02-11 11:00:00', '2021-02-11 11:15:00',
#                '2021-02-11 11:30:00', '2021-02-11 11:45:00',
#                ...
#                '2021-05-12 13:30:00', '2021-05-12 13:45:00',
#                '2021-05-12 14:00:00', '2021-05-12 14:15:00',
#                '2021-05-12 14:30:00', '2021-05-12 14:45:00',
#                '2021-05-12 15:00:00', '2021-05-12 15:15:00',
#                '2021-05-12 15:30:00', '2021-05-12 15:45:00'],
#               dtype='datetime64[ns]', name='price_datetime', length=1638, freq=None)

# %%
df['close_price'].isna().sum()
# Out:
# stock_symbol
# AACG    84
# AAIC     4
# AAME    73
# AAU      0
# ABEO     0
#         ..
# ZNOG    64
# ZOM     52
# ZSAN    52
# ZVO     59
# ZYNE    52
# Length: 645, dtype: int64

# %% [markdown]
# *Use the cell below to test the data to make sure everything is working as it should.*

# %%
# testing the sets w/ matplotlib
plt.figure(figsize=(14,4))
plt.plot(df['close_price']['DSS'])
# plt.plot(test_data['FCEL'])
plt.ylabel('Close Price')
plt.xlabel('Datetime')
plt.legend(["Training set", "Test set"])
plt.title("FCEL close price")
plt.show()

# %% [markdown]
# *The above is what is weird. The data I have is clearly fine, but when splitting it up for training/testing, it gets messed up. Going to work on getting my training/test split directly from the original dataframe instead of the way it is currently working*

# %% [markdown]
# ## Test-train split below
# Uses close prices only. Will try a future version that uses all available data.

# %%
# first cell for test-train split
data = df['close_price']
# data = data.reset_index()

# I am doing this differently. I am using 80% as training data, 20% as test
data_size = len(data)
training_data = data.iloc[:(int(data_size * .8))]
test_data = data.iloc[(int(data_size * .8)):]

# %%
# a lot of my nan's are occuring in the above cell for some reason? going to try imputing that data
# try running this one instead of the above cell
data = df['close_price']
# data = data.reset_index()
columns = df.close_price.columns
imputer = KNNImputer(n_neighbors=100, weights='distance')
imputed_data = imputer.fit_transform(df[['close_price']])
clean_data = pd.DataFrame(imputed_data, columns=columns)
data = clean_data
df = df.reset_index()
data['price_datetime'] = df['price_datetime']

# I am doing this differently. I am using 80% as training data, 20% as test
data_size = len(data)
training_data = data.iloc[:(int(data_size * .8))]
test_data = data.iloc[(int(data_size * .8)):]

# %%
data
# Out:
# stock_symbol      AACG      AAIC      AAME       AAU      ABEO      ABEV  \
# 0             6.230000  3.727000  5.400000  0.920000  3.370000  2.860000
# 1             6.100000  3.740000  5.470000  0.936200  3.304300  2.835000
# 2             5.978300  3.740000  5.420000  0.932201  3.280000  2.840000
# 3             5.997100  3.739000  5.450000  0.948600  3.328100  2.831100
# 4             5.912500  3.725000  5.410000  0.999800  3.310600  2.830000
# ...                ...       ...       ...       ...       ...       ...
# 1672          2.700000  3.905000  4.010000  0.520199  1.400000  3.225000
# 1673          2.720000  3.909900  4.020000  0.519500  1.405000  3.225000
# 1674          2.740000  3.910000  4.190000  0.515100  1.410000  3.220000
# 1675          3.687253  4.074101  4.069917  0.586429  1.775332  2.921762
# 1676          4.260000  3.950000  3.781500  0.531500  1.910000  2.680000
#
# stock_symbol      ABIO      ABML    ABUS      ACER  ...      YTRA       YVR  \
# 0             5.435400  3.686500  4.4300  4.160000  ...  2.647869  2.139294
# 1             5.430000  3.660000  4.5400  4.360000  ...  2.648553  2.140688
# 2             5.350000  3.610000  4.6000  4.400000  ...  2.648475  2.140748
# 3             5.370000  3.620000  4.5292  4.525000  ...  2.648582  2.140886
# 4             5.411100  3.614500  4.5150  4.458200  ...  2.648685  2.141003
# ...                ...       ...     ...       ...  ...       ...       ...
# 1672          3.160000  1.570000  2.6900  2.650989  ...  1.800000  1.900000
# 1673          3.165000  1.570000  2.6950  2.620000  ...  1.793200  1.910000
# 1674          3.190000  1.583500  2.7150  2.610000  ...  1.770000  1.900000
# 1675          3.631313  1.810526  3.2225  2.909972  ...  2.104034  2.369382
# 1676          3.580000  1.640000  3.3050  3.024800  ...  2.280000  3.650000
#
# stock_symbol      ZIOP      ZKIN      ZNOG       ZOM      ZSAN       ZVO  \
# 0             5.001899  6.934171  0.817224  2.310398  1.583381  6.216535
# 1             4.998118  6.921791  0.817810  2.311714  1.585036  6.221170
# 2             4.998172  6.920785  0.817817  2.311604  1.584956  6.220591
# 3             4.997746  6.919908  0.817867  2.311796  1.585148  6.221461
# 4             4.997405  6.919247  0.817914  2.311943  1.585310  6.222231
# ...                ...       ...       ...       ...       ...       ...
# 1672          3.090000  4.600000  0.599000  0.775799  0.746300  3.460000
# 1673          3.085000  4.600000  0.610000  0.771300  0.744800  3.430000
# 1674          3.060000  4.620000  0.610000  0.776700  0.741200  3.430000
# 1675          3.694140  6.298592  0.643429  1.322262  1.014613  4.160846
# 1676          3.460000  9.905000  0.670000  1.602000  1.150000  4.380000
#
# stock_symbol      ZYNE       price_datetime
# 0             5.688334  2021-02-11 09:30:00
# 1             5.689797  2021-02-11 09:45:00
# 2             5.689867  2021-02-11 10:00:00
# 3             5.689999  2021-02-11 10:15:00
# 4             5.690041  2021-02-11 10:30:00
# ...                ...                  ...
# 1672          4.260000  2021-05-12 15:15:00
# 1673          4.250000  2021-05-12 15:30:00
# 1674          4.250000  2021-05-12 15:45:00
# 1675          4.416415  2021-05-12 15:59:18
# 1676          4.512000  2021-05-12 15:59:59
#
# [1677 rows x 646 columns]

# %%
# second cell for test-train split
# adding the price_datetime index back
training_data = training_data.set_index('price_datetime')
test_data = test_data.set_index('price_datetime')

# %%
training_data.isna().sum()
# Out:
# stock_symbol
# AACG    0
# AAIC    0
# AAME    0
# AAU     0
# ABEO    0
#        ..
# ZNOG    0
# ZOM     0
# ZSAN    0
# ZVO     0
# ZYNE    0
# Length: 645, dtype: int64

# %%
# testing the sets w/ matplotlib
plt.figure(figsize=(14,4))
plt.plot(training_data['FCEL'])
plt.plot(test_data['FCEL'])
plt.ylabel('Close Price')
plt.xlabel('Datetime')
plt.legend(["Training set", "Test set"])
plt.title("FCEL close price")
plt.show()

# %% [markdown]
# ## Data Normalization
# This method uses the MinMaxScaler, but a log return can sometimes be more useful.

# %%
# drop security you'd like to predict w/ these lines
# first, it creates a new dataframe w/ only the security you'd like to predict
training_data_predicted = training_data['FCEL']
training_data_predicted = training_data_predicted.to_frame()
training_data_predicted
# Out:
#                           FCEL
# price_datetime
# 2021-02-11 09:30:00  26.930000
# 2021-02-11 09:45:00  26.889999
# 2021-02-11 10:00:00  26.930000
# 2021-02-11 10:15:00  26.860001
# 2021-02-11 10:30:00  26.870001
# ...                        ...
# 2021-04-26 10:45:00  10.250000
# 2021-04-26 11:00:00  10.345000
# 2021-04-26 11:15:00  10.418700
# 2021-04-26 11:30:00  10.479000
# 2021-04-26 11:45:00  10.450000
#
# [1310 rows x 1 columns]

# %%
training_data.shape, training_data_predicted.shape

# %%
# I have altered this so it works better w/ my data.
minmax = MinMaxScaler(feature_range=(0,1))
minmax_single = MinMaxScaler(feature_range=(0,1))

training_data = training_data.drop(columns='FCEL')

# no idea if the line below will work the way I need it to or not
train_scaled = np.concatenate([minmax.fit_transform(training_data.values), minmax_single.fit_transform(training_data_predicted.values)], axis=1)

columns = [i for i in training_data.columns]
columns.append('FCEL')

train_scaled = pd.DataFrame(train_scaled, columns=columns)
train_scaled
# Out:
#           AACG      AAIC      AAME       AAU      ABEO      ABEV      ABIO  \
# 0     0.966866  0.102667  0.669698  0.851893  0.922018  0.817769  0.997900
# 1     0.930851  0.120000  0.691503  0.881960  0.891881  0.772348  0.995434
# 2     0.897135  0.120000  0.675928  0.874538  0.880734  0.781432  0.958904
# 3     0.902344  0.118667  0.685273  0.904974  0.902798  0.765262  0.968036
# 4     0.878906  0.100000  0.672813  1.000000  0.894771  0.763263  0.986804
# ...        ...       ...       ...       ...       ...       ...       ...
# 1305  0.063719  0.653333  0.274109  0.209169  0.153670  0.917696  0.146119
# 1306  0.060949  0.680000  0.277224  0.211117  0.155963  0.902253  0.154566
# 1307  0.066489  0.680000  0.292487  0.207684  0.155963  0.895349  0.150685
# 1308  0.066462  0.653333  0.295913  0.206941  0.169725  0.890444  0.150685
# 1309  0.063719  0.653333  0.277255  0.202301  0.166560  0.881359  0.150685
#
#           ABML      ABUS      ACER  ...      YTRA       YVR      ZIOP  \
# 0     0.898661  0.892857  0.720034  ...       NaN       NaN       NaN
# 1     0.889813  0.958333  0.810360  ...       NaN       NaN       NaN
# 2     0.873118  0.994047  0.828426  ...       NaN       NaN       NaN
# 3     0.876457  0.951905  0.884879  ...       NaN       NaN       NaN
# 4     0.874620  0.943452  0.854710  ...       NaN       NaN       NaN
# ...        ...       ...       ...  ...       ...       ...       ...
# 1305  0.250392  0.250000       NaN  ...  0.113636  0.265368  0.154959
# 1306  0.238706  0.261905  0.196143  ...  0.125000  0.253007  0.154959
# 1307  0.243714  0.258929  0.187110  ...  0.142045  0.254861  0.154959
# 1308  0.242045  0.250000  0.187110  ...  0.147727  0.258234  0.154959
# 1309  0.232028  0.252976       NaN  ...  0.170455  0.263991  0.146694
#
#           ZKIN      ZNOG       ZOM      ZSAN       ZVO      ZYNE      FCEL
# 0          NaN       NaN       NaN       NaN       NaN       NaN  1.000000
# 1          NaN       NaN       NaN       NaN       NaN       NaN  0.997842
# 2          NaN       NaN       NaN       NaN       NaN       NaN  1.000000
# 3          NaN       NaN       NaN       NaN       NaN       NaN  0.996224
# 4          NaN       NaN       NaN       NaN       NaN       NaN  0.996764
# ...        ...       ...       ...       ...       ...       ...       ...
# 1305  0.251599  0.223881  0.113054  0.174917  0.070227  0.311870  0.100324
# 1306  0.256429  0.223881  0.122093  0.178918  0.098317  0.304122  0.105448
# 1307  0.248401  0.191898  0.123080  0.179828  0.095508  0.300248  0.109423
# 1308  0.249467  0.170576  0.140447  0.187719  0.096070  0.311870  0.112675
# 1309  0.250181  0.170789  0.145926  0.186119  0.134835  0.307454  0.111111
#
# [1310 rows x 645 columns]

# %%
# validate min/max values
train_scaled.describe()

# %% [markdown]
# ## Shaping data for LSTM

# %%
train_scaled = train_scaled.values
n_lags = int(60) # not sure why hard 60
X_train = []
y_train = []
for i in range(n_lags, train_scaled.shape[0]):
    X_train.append(train_scaled[i-n_lags:i])
    y_train.append(train_scaled[i,0])

X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], -1))

# check shape (again) before start training
'''shape_chk = []
for i in train_scaled.close_price.columns:
    index = {}
    index["X_train"] = X_train.shape
    index["y_train"] = y_train.shape
    shape_chk.append(index)
pd.DataFrame(shape_chk)'''
# Out:
# 'shape_chk = []\nfor i in train_scaled.close_price.columns:\n    index = {}\n    index["X_train"] = X_train.shape\n    index["y_train"] = y_train.shape\n    shape_chk.append(index)\npd.DataFrame(shape_chk)'

# %%
X_train.shape, y_train.shape

# %% [markdown]
# ## Build the LSTM network

# %%
# %time

# LSTM architecture
regressor = tf.keras.Sequential()

# Layer 1, w/ dropout regularisation
regressor.add(tf.keras.layers.LSTM(units=20, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
regressor.add(tf.keras.layers.Dropout(0.3))

# Layer 2
regressor.add(tf.keras.layers.LSTM(units=20, return_sequences=True))
regressor.add(tf.keras.layers.Dropout(0.3))

# Layer 3
regressor.add(tf.keras.layers.LSTM(units=20, return_sequences=True))
regressor.add(tf.keras.layers.Dropout(0.6))

# Layer 4
regressor.add(tf.keras.layers.LSTM(units=20))
regressor.add(tf.keras.layers.Dropout(0.6))

# Output layer
regressor.add(tf.keras.layers.Dense(units=1))

# Compile LSTM
regressor.compile(optimizer='adam', loss='mean_squared_error')

# fit to training set
num_features = len(training_data.columns)
progress = 1
for i in training_data.columns:
    print("Fitting to", i)
    print("Training feature", progress, "of", num_features)
    regressor.fit(X_train, y_train, epochs=20, batch_size=32, verbose=0)
    progress += 1
# Out:
# 7 of 644
# Fitting to DGLY
# Training feature 188 of 644
# Fitting to DHC
# Training feature 189 of 644
# Fitting to DHX
# Training feature 190 of 644
# Fitting to DMGGF
# Training feature 191 of 644
# Fitting to DNN
# Training feature 192 of 644
# Fitting to DPW
# Training feature 193 of 644
# Fitting to DRRX
# Training feature 194 of 644
# Fitting to DS
# Training feature 195 of 644
# Fitting to DSS
# Training feature 196 of 644
# Fitting to DSX
# Training feature 197 of 644
# Fitting to DVAX
# Training feature 198 of 644
# Fitting to EARS
# Training feature 199 of 644
# Fitting to ECOR
# Training feature 200 of 644
# Fitting to EGY
# Training feature 201 of 644
# Fitting to ELVT
# Training feature 202 of 644
# Fitting to EMAN
# Training feature 203 of 644
# Fitting to EMX
# Training feature 204 of 644
# Fitting to ENG
# Training feature 205 of 644
# Fitting to ENIC
# Training feature 206 of 644
# Fitting to ENLC
# Training feature 207 of 644
# Fitting to ENSV
# Training feature 208 of 644
# Fitting to ENTX
# Training feature 209 of 644
# Fitting to ENZ
# Training feature 210 of 644
# Fitting to EOLS
# Training feature 211 of 644
# Fitting to EPM
# Training feature 212 of 644
# Fitting to ERF
# Training feature 213 of 644
# Fitting to ESGC
# Training feature 214 of 644
# Fitting to EVC
# Training feature 215 of 644
# Fitting to EVFM
# Training feature 216 of 644
# Fitting to EVGN
# Training feature 217 of 644
# Fitting to EVOK
# Training feature 218 of 644
# Fitting to EXPR
# Training feature 219 of 644
# Fitting to EXTN
# Training feature 220 of 644
# Fitting to EYES
# Training feature 221 of 644
# Fitting to EZPW
# Training feature 222 of 644
# Fitting to FAMI
# Training feature 223 of 644
# Fitting to FARM
# Training feature 224 of 644
# Fitting to FBIO
# Training feature 225 of 644
# Fitting to FENG
# Training feature 226 of 644
# Fitting to FFNTF
# Training feature 227 of 644
# Fitting to FI
# Training feature 228 of 644
# Fitting to FINV
# Training feature 229 of 644
# Fitting to FLL
# Training feature 230 of 644
# Fitting to FLMN
# Training feature 231 of 644
# Fitting to FMCC
# Training feature 232 of 644
# Fitting to FNMA
# Training feature 233 of 644
# Fitting to FRBK
# Training feature 234 of 644
# Fitting to FRSX
# Training feature 235 of 644
# Fitting to FSP
# Training feature 236 of 644
# Fitting to FTEK
# Training feature 237 of 644
# Fitting to FTFT
# Training feature 238 of 644
# Fitting to FTK
# Training feature 239 of 644
# Fitting to GALT
# Training feature 240 of 644
# Fitting to GAU
# Training feature 241 of 644
# Fitting to GAXY
# Training feature 242 of 644
# Fitting to GBR
# Training feature 243 of 644
# Fitting to GCI
# Training feature 244 of 644
# Fitting to GERN
# Training feature 245 of 644
# Fitting to GEVO
# Training feature 246 of 644
# Fitting to GGB
# Training feature 247 of 644
# Fitting to GGTTF
# Training feature 248 of 644
# Fitting to GHSI
# Training feature 249 of 644
# Fitting to GLDG
# Training feature 250 of 644
# Fitting to GLOG
# Training feature 251 of 644
# Fitting to GLOP
# Training feature 252 of 644
# Fitting to GLYC
# Training feature 253 of 644
# Fitting to GME
# Training feature 254 of 644
# Fitting to GNCA
# Training feature 255 of 644
# Fitting to GNLN
# Training feature 256 of 644
# Fitting to GNPX
# Training feature 257 of 644
# Fitting to GNUS
# Training feature 258 of 644
# Fitting to GNW
# Training feature 259 of 644
# Fitting to GOGL
# Training feature 260 of 644
# Fitting to GORO
# Training feature 261 of 644
# Fitting to GOVX
# Training feature 262 of 644
# Fitting to GPL
# Training feature 263 of 644
# Fitting to GRIL
# Training feature 264 of 644
# Fitting to GRNQ
# Training feature 265 of 644
# Fitting to GRTS
# Training feature 266 of 644
# Fitting to GSAT
# Training feature 267 of 644
# Fitting to GSKY
# Training feature 268 of 644
# Fitting to GSM
# Training feature 269 of 644
# Fitting to GSS
# Training feature 270 of 644
# Fitting to GSV
# Training feature 271 of 644
# Fitting to GTBP
# Training feature 272 of 644
# Fitting to GTE
# Training feature 273 of 644
# Fitting to GTT
# Training feature 274 of 644
# Fitting to HBIO
# Training feature 275 of 644
# Fitting to HCDI
# Training feature 276 of 644
# Fitting to HCHC
# Training feature 277 of 644
# Fitting to HDSN
# Training feature 278 of 644
# Fitting to HEPA
# Training feature 279 of 644
# Fitting to HEXO
# Training feature 280 of 644
# Fitting to HIMX
# Training feature 281 of 644
# Fitting to HITIF
# Training feature 282 of 644
# Fitting to HLX
# Training feature 283 of 644
# Fitting to HMHC
# Training feature 284 of 644
# Fitting to HMY
# Training feature 285 of 644
# Fitting to HOFV
# Training feature 286 of 644
# Fitting to HOTH
# Training feature 287 of 644
# Fitting to HRVSF
# Training feature 288 of 644
# Fitting to HSTO
# Training feature 289 of 644
# Fitting to HTBX
# Training feature 290 of 644
# Fitting to HUGE
# Training feature 291 of 644
# Fitting to HUSA
# Training feature 292 of 644
# Fitting to HUTMF
# Training feature 293 of 644
# Fitting to HVBTF
# Training feature 294 of 644
# Fitting to IAG
# Training feature 295 of 644
# Fitting to IBIO
# Training feature 296 of 644
# Fitting to ICD
# Training feature 297 of 644
# Fitting to IDEX
# Training feature 298 of 644
# Fitting to IDRA
# Training feature 299 of 644
# Fitting to IGC
# Training feature 300 of 644
# Fitting to IMGN
# Training feature 301 of 644
# Fitting to IMMP
# Training feature 302 of 644
# Fitting to INFI
# Training feature 303 of 644
# Fitting to INO
# Training feature 304 of 644
# Fitting to INPX
# Training feature 305 of 644
# Fitting to INTV
# Training feature 306 of 644
# Fitting to INUV
# Training feature 307 of 644
# Fitting to IO
# Training feature 308 of 644
# Fitting to ISR
# Training feature 309 of 644
# Fitting to ITP
# Training feature 310 of 644
# Fitting to ITRM
# Training feature 311 of 644
# Fitting to IVR
# Training feature 312 of 644
# Fitting to IZEA
# Training feature 313 of 644
# Fitting to JAGX
# Training feature 314 of 644
# Fitting to JFIN
# Training feature 315 of 644
# Fitting to JFU
# Training feature 316 of 644
# Fitting to JG
# Training feature 317 of 644
# Fitting to JOB
# Training feature 318 of 644
# Fitting to JUVAF
# Training feature 319 of 644
# Fitting to KDMN
# Training feature 320 of 644
# Fitting to KERN
# Training feature 321 of 644
# Fitting to KIN
# Training feature 322 of 644
# Fitting to KIQ
# Training feature 323 of 644
# Fitting to KOPN
# Training feature 324 of 644
# Fitting to KOS
# Training feature 325 of 644
# Fitting to KOSS
# Training feature 326 of 644
# Fitting to KSHB
# Training feature 327 of 644
# Fitting to KTRA
# Training feature 328 of 644
# Fitting to KXIN
# Training feature 329 of 644
# Fitting to LAIX
# Training feature 330 of 644
# Fitting to LCTX
# Training feature 331 of 644
# Fitting to LEAF
# Training feature 332 of 644
# Fitting to LGHL
# Training feature 333 of 644
# Fitting to LIACF
# Training feature 334 of 644
# Fitting to LIFE
# Training feature 335 of 644
# Fitting to LITB
# Training feature 336 of 644
# Fitting to LIVX
# Training feature 337 of 644
# Fitting to LIZI
# Training feature 338 of 644
# Fitting to LJPC
# Training feature 339 of 644
# Fitting to LKCO
# Training feature 340 of 644
# Fitting to LLNW
# Training feature 341 of 644
# Fitting to LMFA
# Training feature 342 of 644
# Fitting to LMNL
# Training feature 343 of 644
# Fitting to LODE
# Training feature 344 of 644
# Fitting to LPCN
# Training feature 345 of 644
# Fitting to LPTH
# Training feature 346 of 644
# Fitting to LPTX
# Training feature 347 of 644
# Fitting to LQDA
# Training feature 348 of 644
# Fitting to LTRPA
# Training feature 349 of 644
# Fitting to LTRX
# Training feature 350 of 644
# Fitting to LXRX
# Training feature 351 of 644
# Fitting to LXU
# Training feature 352 of 644
# Fitting to LYG
# Training feature 353 of 644
# Fitting to LYL
# Training feature 354 of 644
# Fitting to MARK
# Training feature 355 of 644
# Fitting to MBII
# Training feature 356 of 644
# Fitting to MBIO
# Training feature 357 of 644
# Fitting to MBRX
# Training feature 358 of 644
# Fitting to MCF
# Training feature 359 of 644
# Fitting to MDGS
# Training feature 360 of 644
# Fitting to MDRR
# Training feature 361 of 644
# Fitting to MEIP
# Training feature 362 of 644
# Fitting to METX
# Training feature 363 of 644
# Fitting to MFA
# Training feature 364 of 644
# Fitting to MFG
# Training feature 365 of 644
# Fitting to MHLD
# Training feature 366 of 644
# Fitting to MICT
# Training feature 367 of 644
# Fitting to MITT
# Training feature 368 of 644
# Fitting to MKD
# Training feature 369 of 644
# Fitting to MKGI
# Training feature 370 of 644
# Fitting to MLND
# Training feature 371 of 644
# Fitting to MLSS
# Training feature 372 of 644
# Fitting to MMNFF
# Training feature 373 of 644
# Fitting to MNKD
# Training feature 374 of 644
# Fitting to MOGO
# Training feature 375 of 644
# Fitting to MOSY
# Training feature 376 of 644
# Fitting to MOTS
# Training feature 377 of 644
# Fitting to MREO
# Training feature 378 of 644
# Fitting to MRIN
# Training feature 379 of 644
# Fitting to MRKR
# Training feature 380 of 644
# Fitting to MRMD
# Training feature 381 of 644
# Fitting to MTNB
# Training feature 382 of 644
# Fitting to MUFG
# Training feature 383 of 644
# Fitting to MUX
# Training feature 384 of 644
# Fitting to NAK
# Training feature 385 of 644
# Fitting to NAKD
# Training feature 386 of 644
# Fitting to NAOV
# Training feature 387 of 644
# Fitting to NAT
# Training feature 388 of 644
# Fitting to NBEV
# Training feature 389 of 644
# Fitting to NBRV
# Training feature 390 of 644
# Fitting to NBY
# Training feature 391 of 644
# Fitting to NCMI
# Training feature 392 of 644
# Fitting to NCNA
# Training feature 393 of 644
# Fitting to NCTY
# Training feature 394 of 644
# Fitting to NDRA
# Training feature 395 of 644
# Fitting to NEPT
# Training feature 396 of 644
# Fitting to NERV
# Training feature 397 of 644
# Fitting to NEX
# Training feature 398 of 644
# Fitting to NEXT
# Training feature 399 of 644
# Fitting to NGD
# Training feature 400 of 644
# Fitting to NGL
# Training feature 401 of 644
# Fitting to NH
# Training feature 402 of 644
# Fitting to NLST
# Training feature 403 of 644
# Fitting to NM
# Training feature 404 of 644
# Fitting to NMTR
# Training feature 405 of 644
# Fitting to NOK
# Training feature 406 of 644
# Fitting to NOVN
# Training feature 407 of 644
# Fitting to NR
# Training feature 408 of 644
# Fitting to NSPR
# Training feature 409 of 644
# Fitting to NVCN
# Training feature 410 of 644
# Fitting to NVIV
# Training feature 411 of 644
# Fitting to NWBO
# Training feature 412 of 644
# Fitting to NWG
# Training feature 413 of 644
# Fitting to NXE
# Training feature 414 of 644
# Fitting to NXTD
# Training feature 415 of 644
# Fitting to NYMT
# Training feature 416 of 644
# Fitting to NYMX
# Training feature 417 of 644
# Fitting to OBLN
# Training feature 418 of 644
# Fitting to OBSV
# Training feature 419 of 644
# Fitting to OCG
# Training feature 420 of 644
# Fitting to OCGN
# Training feature 421 of 644
# Fitting to OCX
# Training feature 422 of 644
# Fitting to OEG
# Training feature 423 of 644
# Fitting to OGEN
# Training feature 424 of 644
# Fitting to OGI
# Training feature 425 of 644
# Fitting to ONCT
# Training feature 426 of 644
# Fitting to ONCY
# Training feature 427 of 644
# Fitting to ONE
# Training feature 428 of 644
# Fitting to ONTX
# Training feature 429 of 644
# Fitting to OPGN
# Training feature 430 of 644
# Fitting to OPK
# Training feature 431 of 644
# Fitting to OPTN
# Training feature 432 of 644
# Fitting to OPTT
# Training feature 433 of 644
# Fitting to ORMP
# Training feature 434 of 644
# Fitting to ORN
# Training feature 435 of 644
# Fitting to ORTX
# Training feature 436 of 644
# Fitting to OSG
# Training feature 437 of 644
# Fitting to OSMT
# Training feature 438 of 644
# Fitting to OSS
# Training feature 439 of 644
# Fitting to OTLK
# Training feature 440 of 644
# Fitting to OVID
# Training feature 441 of 644
# Fitting to OXSQ
# Training feature 442 of 644
# Fitting to PACB
# Training feature 443 of 644
# Fitting to PAVM
# Training feature 444 of 644
# Fitting to PAYS
# Training feature 445 of 644
# Fitting to PDSB
# Training feature 446 of 644
# Fitting to PED
# Training feature 447 of 644
# Fitting to PEI
# Training feature 448 of 644
# Fitting to PFMT
# Training feature 449 of 644
# Fitting to PHAS
# Training feature 450 of 644
# Fitting to PHIO
# Training feature 451 of 644
# Fitting to PHUN
# Training feature 452 of 644
# Fitting to PIRS
# Training feature 453 of 644
# Fitting to PIXY
# Training feature 454 of 644
# Fitting to PLG
# Training feature 455 of 644
# Fitting to PLIN
# Training feature 456 of 644
# Fitting to PLM
# Training feature 457 of 644
# Fitting to PLUG
# Training feature 458 of 644
# Fitting to PLX
# Training feature 459 of 644
# Fitting to PNNT
# Training feature 460 of 644
# Fitting to POAI
# Training feature 461 of 644
# Fitting to POLA
# Training feature 462 of 644
# Fitting to POWW
# Training feature 463 of 644
# Fitting to PPBT
# Training feature 464 of 644
# Fitting to PRPO
# Training feature 465 of 644
# Fitting to PRQR
# Training feature 466 of 644
# Fitting to PSTV
# Training feature 467 of 644
# Fitting to PT
# Training feature 468 of 644
# Fitting to PTE
# Training feature 469 of 644
# Fitting to PTN
# Training feature 470 of 644
# Fitting to PULM
# Training feature 471 of 644
# Fitting to PXLW
# Training feature 472 of 644
# Fitting to PXS
# Training feature 473 of 644
# Fitting to QD
# Training feature 474 of 644
# Fitting to QLGN
# Training feature 475 of 644
# Fitting to QTT
# Training feature 476 of 644
# Fitting to QUAD
# Training feature 477 of 644
# Fitting to RAIL
# Training feature 478 of 644
# Fitting to RAVE
# Training feature 479 of 644
# Fitting to RCON
# Training feature 480 of 644
# Fitting to RECAF
# Training feature 481 of 644
# Fitting to REED
# Training feature 482 of 644
# Fitting to REFR
# Training feature 483 of 644
# Fitting to REI
# Training feature 484 of 644
# Fitting to REPH
# Training feature 485 of 644
# Fitting to RES
# Training feature 486 of 644
# Fitting to RESN
# Training feature 487 of 644
# Fitting to RGLS
# Training feature 488 of 644
# Fitting to RIBT
# Training feature 489 of 644
# Fitting to RIG
# Training feature 490 of 644
# Fitting to RIGL
# Training feature 491 of 644
# Fitting to RKDA
# Training feature 492 of 644
# Fitting to RMNI
# Training feature 493 of 644
# Fitting to RMTI
# Training feature 494 of 644
# Fitting to RNWK
# Training feature 495 of 644
# Fitting to RRD
# Training feature 496 of 644
# Fitting to RWLK
# Training feature 497 of 644
# Fitting to SACH
# Training feature 498 of 644
# Fitting to SALM
# Training feature 499 of 644
# Fitting to SAN
# Training feature 500 of 644
# Fitting to SB
# Training feature 501 of 644
# Fitting to SBBP
# Training feature 502 of 644
# Fitting to SCKT
# Training feature 503 of 644
# Fitting to SCOR
# Training feature 504 of 644
# Fitting to SD
# Training feature 505 of 644
# Fitting to SEAC
# Training feature 506 of 644
# Fitting to SEEL
# Training feature 507 of 644
# Fitting to SELB
# Training feature 508 of 644
# Fitting to SENS
# Training feature 509 of 644
# Fitting to SESN
# Training feature 510 of 644
# Fitting to SFET
# Training feature 511 of 644
# Fitting to SGLB
# Training feature 512 of 644
# Fitting to SHIP
# Training feature 513 of 644
# Fitting to SHMP
# Training feature 514 of 644
# Fitting to SIEB
# Training feature 515 of 644
# Fitting to SIEN
# Training feature 516 of 644
# Fitting to SIFY
# Training feature 517 of 644
# Fitting to SINO
# Training feature 518 of 644
# Fitting to SINT
# Training feature 519 of 644
# Fitting to SIOX
# Training feature 520 of 644
# Fitting to SLGG
# Training feature 521 of 644
# Fitting to SLNO
# Training feature 522 of 644
# Fitting to SLRX
# Training feature 523 of 644
# Fitting to SMTS
# Training feature 524 of 644
# Fitting to SNCR
# Training feature 525 of 644
# Fitting to SND
# Training feature 526 of 644
# Fitting to SNDL
# Training feature 527 of 644
# Fitting to SNES
# Training feature 528 of 644
# Fitting to SNGX
# Training feature 529 of 644
# Fitting to SNMP
# Training feature 530 of 644
# Fitting to SONM
# Training feature 531 of 644
# Fitting to SONN
# Training feature 532 of 644
# Fitting to SOS
# Training feature 533 of 644
# Fitting to SPCB
# Training feature 534 of 644
# Fitting to SPPI
# Training feature 535 of 644
# Fitting to SPRWF
# Training feature 536 of 644
# Fitting to SRAX
# Training feature 537 of 644
# Fitting to SREV
# Training feature 538 of 644
# Fitting to SRGA
# Training feature 539 of 644
# Fitting to SSFT
# Training feature 540 of 644
# Fitting to SSY
# Training feature 541 of 644
# Fitting to STAF
# Training feature 542 of 644
# Fitting to STON
# Training feature 543 of 644
# Fitting to STSA
# Training feature 544 of 644
# Fitting to SUP
# Training feature 545 of 644
# Fitting to SUPV
# Training feature 546 of 644
# Fitting to SVRA
# Training feature 547 of 644
# Fitting to SWN
# Training feature 548 of 644
# Fitting to SXC
# Training feature 549 of 644
# Fitting to SXTC
# Training feature 550 of 644
# Fitting to SYBX
# Training feature 551 of 644
# Fitting to SYN
# Training feature 552 of 644
# Fitting to SYPR
# Training feature 553 of 644
# Fitting to TAKOF
# Training feature 554 of 644
# Fitting to TANH
# Training feature 555 of 644
# Fitting to TAOP
# Training feature 556 of 644
# Fitting to TBLT
# Training feature 557 of 644
# Fitting to TEF
# Training feature 558 of 644
# Fitting to TELL
# Training feature 559 of 644
# Fitting to TGB
# Training feature 560 of 644
# Fitting to TGODF
# Training feature 561 of 644
# Fitting to TH
# Training feature 562 of 644
# Fitting to TK
# Training feature 563 of 644
# Fitting to TLGT
# Training feature 564 of 644
# Fitting to TMBR
# Training feature 565 of 644
# Fitting to TMDI
# Training feature 566 of 644
# Fitting to TMQ
# Training feature 567 of 644
# Fitting to TMRC
# Training feature 568 of 644
# Fitting to TMST
# Training feature 569 of 644
# Fitting to TNXP
# Training feature 570 of 644
# Fitting to TOBAF
# Training feature 571 of 644
# Fitting to TOPS
# Training feature 572 of 644
# Fitting to TOUR
# Training feature 573 of 644
# Fitting to TRCH
# Training feature 574 of 644
# Fitting to TRIB
# Training feature 575 of 644
# Fitting to TRTC
# Training feature 576 of 644
# Fitting to TRUE
# Training feature 577 of 644
# Fitting to TRVG
# Training feature 578 of 644
# Fitting to TRVN
# Training feature 579 of 644
# Fitting to TRX
# Training feature 580 of 644
# Fitting to TTI
# Training feature 581 of 644
# Fitting to TTNP
# Training feature 582 of 644
# Fitting to TTOO
# Training feature 583 of 644
# Fitting to TWI
# Training feature 584 of 644
# Fitting to TXMD
# Training feature 585 of 644
# Fitting to TYME
# Training feature 586 of 644
# Fitting to UEC
# Training feature 587 of 644
# Fitting to UGP
# Training feature 588 of 644
# Fitting to UONE
# Training feature 589 of 644
# Fitting to UONEK
# Training feature 590 of 644
# Fitting to URG
# Training feature 591 of 644
# Fitting to USAS
# Training feature 592 of 644
# Fitting to USWS
# Training feature 593 of 644
# Fitting to UUUU
# Training feature 594 of 644
# Fitting to UXIN
# Training feature 595 of 644
# Fitting to VBIV
# Training feature 596 of 644
# Fitting to VBLT
# Training feature 597 of 644
# Fitting to VCNX
# Training feature 598 of 644
# Fitting to VEON
# Training feature 599 of 644
# Fitting to VERB
# Training feature 600 of 644
# Fitting to VERI
# Training feature 601 of 644
# Fitting to VERO
# Training feature 602 of 644
# Fitting to VET
# Training feature 603 of 644
# Fitting to VISL
# Training feature 604 of 644
# Fitting to VIST
# Training feature 605 of 644
# Fitting to VIVE
# Training feature 606 of 644
# Fitting to VLNCF
# Training feature 607 of 644
# Fitting to VNRX
# Training feature 608 of 644
# Fitting to VNTR
# Training feature 609 of 644
# Fitting to VRAY
# Training feature 610 of 644
# Fitting to VSTM
# Training feature 611 of 644
# Fitting to VTGN
# Training feature 612 of 644
# Fitting to VTNR
# Training feature 613 of 644
# Fitting to VTVT
# Training feature 614 of 644
# Fitting to VYGVF
# Training feature 615 of 644
# Fitting to VYNE
# Training feature 616 of 644
# Fitting to WATT
# Training feature 617 of 644
# Fitting to WMC
# Training feature 618 of 644
# Fitting to WRAP
# Training feature 619 of 644
# Fitting to WRN
# Training feature 620 of 644
# Fitting to WTER
# Training feature 621 of 644
# Fitting to WTI
# Training feature 622 of 644
# Fitting to WTRH
# Training feature 623 of 644
# Fitting to WTTR
# Training feature 624 of 644
# Fitting to WWR
# Training feature 625 of 644
# Fitting to XCUR
# Training feature 626 of 644
# Fitting to XELA
# Training feature 627 of 644
# Fitting to XERS
# Training feature 628 of 644
# Fitting to XNET
# Training feature 629 of 644
# Fitting to XPL
# Training feature 630 of 644
# Fitting to XSPA
# Training feature 631 of 644
# Fitting to XXII
# Training feature 632 of 644
# Fitting to YCBD
# Training feature 633 of 644
# Fitting to YJ
# Training feature 634 of 644
# Fitting to YPF
# Training feature 635 of 644
# Fitting to YTRA
# Training feature 636 of 644
# Fitting to YVR
# Training feature 637 of 644
# Fitting to ZIOP
# Training feature 638 of 644
# Fitting to ZKIN
# Training feature 639 of 644
# Fitting to ZNOG
# Training feature 640 of 644
# Fitting to ZOM
# Training feature 641 of 644
# Fitting to ZSAN
# Training feature 642 of 644
# Fitting to ZVO
# Training feature 643 of 644
# Fitting to ZYNE
# Training feature 644 of 644

# %%
regressor.save('model_05202021')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 5 of 20). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model_05202021\assets
# INFO:tensorflow:Assets written to: model_05202021\assets

# %%
regressor = tf.keras.models.load_model('model_05202021')

# %% [markdown]
# ## Predicting future values using the Test set
# To predict future prices, need to do a couple of data processing tasks
# 1. Merge training and test datasets on 0 axis.
# 2. set the n_lags as time steps
# 3. transform the new dataset
# 4. reshape the dataset

# %%
inputs

# %%
predicted_input

# %%
minmax.transform(inputs)

# %%
total_data = pd.concat((training_data, test_data), axis=0)
inputs = total_data[len(total_data) - len(test_data) - 60:]
# inputs = data[len(data) - len(test_data) - 60:]

predicted_input = inputs['FCEL'].to_frame()
inputs = inputs.drop(columns='FCEL')

test_scaled = np.concatenate([minmax.transform(inputs), minmax_single.transform(predicted_input)], axis=1)
print('Shape of test data:', test_scaled.shape)

# shaping test data from neural network
X_test = []
y_test = []
for i in range(60, test_scaled.shape[0]):
    X_test.append(test_scaled[i-n_lags:i])
    y_test.append(test_scaled[i,0])

X_test, y_test = np.array(X_test), np.array(y_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], -1))
# Out:
# Shape of test data: (388, 645)

# %% [markdown]
# Now, inverse the transformed data to get back the prices in a normal readable format.

# %%
predicted_price = regressor.predict(X_test)
predicted_price = minmax_single.inverse_transform(predicted_price)
predicted_price = pd.DataFrame(predicted_price)
predicted_price.rename(columns = {0: 'FCEL_predicted'}, inplace=True)
predicted_price = predicted_price.round(decimals=2)
predicted_price.index = test_data.index

# %%
# Visualization
from sklearn.metrics import mean_squared_error
plt.figure(figsize=(14,5))
#mse = mean_squared_error(y_test, predicted_price)
plt.plot(predicted_price['FCEL_predicted'], color = 'red', label= 'Predicted FCEL Closing Price')
plt.plot(test_data['FCEL'], color = 'green', label = 'Actual FCEL Closing Price')
# plt.title("FCEL Closing PRice Prediction w/ MSE {:10:4f}".format(mse))
plt.title('FCEL Closing Price Prediction')
plt.xlabel("Time")
plt.ylabel('Price USD')
plt.legend()
